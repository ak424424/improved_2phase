# %%
# Knapsack instance example
from numerical_study import *
file = 'kp_instances/KP_p-3_n-40_ins-1.lp-bdd.dat'

study = NumericalStudy(file, problem_type='knapsack')
study.full_study_for_ks()
study.df_results_final
# Out:
# ==== Train runs ====
# Restricted license - for non-production use only - expires 2025-11-24
# Phase I: Pareto optimal soltuions found -  159
# ==== ML model 1 training ====
# 100%|██████████| 50/50 [00:03<00:00, 14.05trial/s, best loss: 0.039198796158957404]
# ==== Numerical study 2 ====
# ==== ML model 2 training ====
# 100%|██████████| 50/50 [00:03<00:00, 14.76trial/s, best loss: -0.7708067951518319]
# ==== Numerical study 1 ====
# ==== ML model 2 training ====
# 100%|██████████| 50/50 [00:03<00:00, 14.95trial/s, best loss: -0.771671087861067]
# ==== Numerical study 1 ====
# ==== ML model 2 training ====
# 100%|██████████| 50/50 [00:03<00:00, 12.51trial/s, best loss: -0.6903264793496243]
# ==== Numerical study 1 ====
# ==== ML model 2 training ====
# 100%|██████████| 50/50 [00:03<00:00, 15.48trial/s, best loss: -0.6487761362009197]
# ==== Numerical study 1 ====
#    p   n Combination # of iterations # of solved IPs  \
# 0  3  40   (1, 0, 2)            3218            1047
# ...

# %%
# Set Covering instance example
from numerical_study import *
file = 'sc_instances/bp-175-35-3-10-12914.dat-bdd.dat'

study = NumericalStudy(file, problem_type='set_covering')
study.full_study_for_ks()
study.df_results_final
# Out:
# ==== Train runs ====
# Phase I: Pareto optimal soltuions found -  147
# ==== ML model 1 training ====
# 100%|██████████| 50/50 [00:03<00:00, 13.53trial/s, best loss: 0.0499605670031701]
# ==== Numerical study 2 ====
# ==== ML model 2 training ====
# 100%|██████████| 50/50 [00:03<00:00, 13.98trial/s, best loss: -0.9185048293138205]
# ==== Numerical study 1 ====
# ==== ML model 2 training ====
# 100%|██████████| 50/50 [00:03<00:00, 13.41trial/s, best loss: -0.7967437769509242]
# ==== Numerical study 1 ====
# ==== ML model 2 training ====
# 100%|██████████| 50/50 [00:04<00:00, 12.16trial/s, best loss: -0.677145448946666]
# ==== Numerical study 1 ====
# ==== ML model 2 training ====
# 100%|██████████| 50/50 [00:03<00:00, 14.30trial/s, best loss: -0.5540596699037683]
# ==== Numerical study 1 ====
#    p    n Combination # of iterations # of solved IPs  \
# 0  3  175   (2, 0, 1)            2407             764
# 0  3  175   (0, 1, 2)            2651             777
# ...
