# %%
# Knapsack instance example
from numerical_study import *
file = 'kp_instances/KP_p-3_n-40_ins-1.lp-bdd.dat'

study = NumericalStudy(file, problem_type='knapsack')
study.full_study_for_ks()
study.df_results_final
# Out:
# ==== Train runs ====
# Restricted license - for non-production use only - expires 2025-11-24
# Phase I: Pareto optimal soltuions found -  159
# ==== ML model 1 training ====
# 100%|██████████| 50/50 [00:03<00:00, 13.72trial/s, best loss: 0.03598054376934619]
# ==== Numerical study 2 ====
# ==== ML model 2 training ====
# 100%|██████████| 50/50 [00:03<00:00, 15.39trial/s, best loss: -0.9478078163745736]
# ==== Numerical study 1 ====
# ==== ML model 2 training ====
# 100%|██████████| 50/50 [00:03<00:00, 13.57trial/s, best loss: -0.7841456542964887]
# ==== Numerical study 1 ====
# ==== ML model 2 training ====
# 100%|██████████| 50/50 [00:03<00:00, 14.70trial/s, best loss: -0.721103587299158]
# ==== Numerical study 1 ====
# ==== ML model 2 training ====
# 100%|██████████| 50/50 [00:03<00:00, 13.88trial/s, best loss: -0.6066473334493618]
# ==== Numerical study 1 ====
#    p   n Combination # of iterations # of solved IPs  \
# 0  3  40   (0, 1, 2)            3033             948
# 0  3  40   (0, 1, 2)            3033             948
# 0  3  40   (0, 1, 2)            2835             954
# 0  3  40   (0, 1, 2)            1688             900
# 0  3  40   (0, 1, 2)            1532             812
# 0  3  40   (0, 1, 2)            1341             812
#
#   # of skipped IPs (relaxations) # of infeasible IPs  \
# 0                           2355                  54
# 0                           2355                  54
# 0                           2151                  56
# 0                           1058                  52
# 0                            990                  51
# 0                            799                  53
#
#   # of Pareto efficient solutions Total time in seconds  \
# 0                             439             12.540697
# 0                             439              12.57327
# 0                             441             12.360433
# 0                             429             11.074228
# 0                             388              9.892127
# 0                             398              9.827925
#
#   Total solver time in seconds        Scenario
# 0                    11.842541   BC, cluster 1
# 0                     11.86919     R cluster 1
# 0                    11.659977  BC, clusters 2
# 0                    10.569205  BC, clusters 3
# 0                     9.433771  BC, clusters 4
# 0                     9.384017  BC, clusters 5

# %%
# Set Covering instance example
from numerical_study import *
file = 'sc_instances/bp-175-35-3-10-12914.dat-bdd.dat'

study = NumericalStudy(file, problem_type='set_covering')
study.full_study_for_ks()
study.df_results_final
# Out:
# ==== Train runs ====
# Phase I: Pareto optimal soltuions found -  184
# ==== ML model 1 training ====
# 100%|██████████| 50/50 [00:03<00:00, 14.90trial/s, best loss: 0.040947944837645835]
# ==== Numerical study 2 ====
# ==== ML model 2 training ====
# 100%|██████████| 50/50 [00:03<00:00, 13.39trial/s, best loss: -0.7943575853362356]
# ==== Numerical study 1 ====
# ==== ML model 2 training ====
# 100%|██████████| 50/50 [00:03<00:00, 12.73trial/s, best loss: -0.5935820684107327]
# ==== Numerical study 1 ====
# ==== ML model 2 training ====
# 100%|██████████| 50/50 [00:03<00:00, 14.07trial/s, best loss: -0.6108611368095486]
# ==== Numerical study 1 ====
# ==== ML model 2 training ====
# 100%|██████████| 50/50 [00:03<00:00, 12.59trial/s, best loss: -0.5926569837569836]
# ==== Numerical study 1 ====
#    p    n Combination # of iterations # of solved IPs  \
# 0  3  175   (1, 2, 0)            3977             839
# 0  3  175   (0, 1, 2)            2651             803
# 0  3  175   (1, 2, 0)            2354             770
# 0  3  175   (1, 2, 0)            2167             726
# 0  3  175   (1, 2, 0)            2137             760
# 0  3  175   (1, 2, 0)            1695             728
#
#   # of skipped IPs (relaxations) # of infeasible IPs  \
# 0                           3455                  36
# 0                           2165                  44
# 0                           1901                  35
# 0                           1758                  34
# 0                           1694                  35
# 0                           1284                  33
#
#   # of Pareto efficient solutions Total time in seconds  \
# 0                             334               8.10939
# 0                             331              7.613141
# 0                             319              7.282961
# 0                             297              6.697305
# 0                             314              7.142723
# 0                             307              6.591021
#
#   Total solver time in seconds        Scenario
# 0                     7.194694   BC, cluster 1
# 0                     6.956419     R cluster 1
# 0                     6.603101  BC, clusters 2
# 0                     6.045493  BC, clusters 3
# 0                     6.494932  BC, clusters 4
# 0                     6.047491  BC, clusters 5
